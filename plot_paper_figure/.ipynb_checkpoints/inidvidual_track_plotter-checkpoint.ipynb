# %% [markdown]
# ## Import

# %%
import os
from os.path import dirname
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as clr
from matplotlib import cm
import scipy.stats as stats
import seaborn as sns

sns.set(color_codes=True, style="white")
pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ## color and saving

# %%
color = "#9a3324"

cmap_color_start = "#00274C"
cmap_color_end = "#FFCB05"
cmap_name = "blue2maize"

folder_save = "/Volumes/lsa-nwalter/Guoming_Gao_turbo/Walterlab_server/PROCESSED_DATA/RNA-diffusion-in-FUS/RNAinFUS_PaperFigures/Fig1_system design/c_boundary_w_RNAtracks/example_zoomed_in_tracks"
os.chdir(folder_save)

fname_save_prefix = "zoomed_in_RNA_track-constrained-2"

# %% [markdown]
# ## Raw data for the track (Option 1: Mannualy input)

# %%
t = np.array([129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174])

x = np.array([196.04033809341496, 196.2996834822327, 196.10555688310464, 195.98803661821265, 196.24449245080964, 195.89856757634857, 195.98638822647032, 196.0167757146842, 196.029942906356, 195.8436228920073, 195.8460479045577, 195.88095698518973, 196.05681161306416, 196.0466093969005, 195.8854667880617, 195.8670984415492, 195.84614545988325, 195.8486328109484, 195.71807589586825, 195.95604860328987, 195.7000923180545, 195.68675919181933, 195.96062140802275, 195.8295536446716, 195.6294397733459, 195.89975197638407, 195.827205172141, 195.7246176027432, 195.8259209381348, 195.62852799197023, 195.8694558896512, 195.44686772763217, 195.78928959551712, 195.9149336053515, 195.5214009073171, 195.6616253645392, 195.62078191927225, 195.80278338146445, 195.7001793830268, 195.76006138834552, 195.22397186335647, 195.91014465990563, 195.51967255519733, 195.82642275589507, 195.84633524930967, 195.8696965490756])

y = np.array([559.2648647995641, 559.2551362339618, 559.6357622616753, 559.265691465067, 559.6721661991331, 559.3106833607374, 559.3598801134758, 559.0972269432737, 559.3695300164527, 559.3658567929247, 559.4105520905091, 559.1911036314675, 559.6663519621868, 559.1369340953994, 559.3773778136859, 559.0146569466882, 558.9009265942402, 558.97714743393, 559.0082604883515, 559.2580354080541, 559.0253399074791, 558.9043089205514, 558.827321403366, 559.0835890725145, 559.2756165784833, 559.3682337278674, 559.0452524020887, 559.0490471924219, 559.1323015045649, 559.6475231160948, 559.6297112929808, 559.5683856873412, 559.6255112298871, 559.7356109700804, 559.2040849173129, 559.3643607421582, 559.5968659066597, 559.4722809620137, 559.0416844416707, 559.3524046627641, 559.507653902867, 559.8817003950305, 559.3363142732115, 559.5033866461041, 559.4816762286143, 559.3644680307622])

MSD = np.array([0.0017375135872859603, 0.001664603462628028, 0.002070046583320598, 0.0017574521957453497, 0.002015447599707958, 0.0018529022242017928, 0.0022352306730462654, 0.002174036867675529, 0.002694065956317604, 0.002504909191117334, 0.002373915693436566, 0.002884006754384488, 0.0030944872487858686, 0.00351603055252931, 0.003327360638204802, 0.0032825032213860566, 0.003281461631182399, 0.003382196694396904, 0.003382587987154617, 0.0034487692746541327, 0.003155061778757594, 0.003305171042416073, 0.0036191082483332756, 0.0034703779866460363, 0.0033213084714690893, 0.003552649200101778, 0.003219270675480809, 0.0034392331570455726, 0.002895668314112434, 0.003682234159478152, 0.002689416725807685, 0.0032004761914102148, 0.0033266998966694997, 0.0037257798032231874, 0.0030751369561982686, 0.0041317989119776955, 0.002882401744984116, 0.00419791608317123, 0.003674590051290581, 0.0045260693783955915, 0.003859644743656402, 0.0023151560780412064, 0.0022300662713377567])

tau = np.array([0.02, 0.04, 0.06, 0.08, 0.1, 0.12, 0.14, 0.16, 0.18, 0.2, 0.22, 0.24, 0.26, 0.28, 0.3, 0.32, 0.34, 0.36, 0.38, 0.4, 0.42, 0.44, 0.46, 0.48, 0.5, 0.52, 0.54, 0.56, 0.58, 0.6, 0.62, 0.64, 0.66, 0.68, 0.7000000000000001, 0.72, 0.74, 0.76, 0.78, 0.8, 0.8200000000000001, 0.84, 0.86])

# %% [markdown]
# ## Transform to physical unit

# %%
nm_per_pxl = 117
s_per_frame = 0.02

x = (x - (x.min() + x.max())/2) * nm_per_pxl
y = (y - (y.min() + y.max())/2) * nm_per_pxl
t = (t - t[0]) * s_per_frame

# %% [markdown]
# ## Raw data for the track (Option 2: from file)

# %%
if False:
    df_load = pd.read_csv(fname_save_prefix + "-data.csv")
    t = df_load[df_load["variable"] == "t_s"]["value"].to_numpy(dtype=float)
    x = df_load[df_load["variable"] == "x_nm"]["value"].to_numpy(dtype=float)
    y = df_load[df_load["variable"] == "y_nm"]["value"].to_numpy(dtype=float)
    MSD = df_load[df_load["variable"] == "MSD_um2"]["value"].to_numpy(dtype=float)
    tau = df_load[df_load["variable"] == "tau_s"]["value"].to_numpy(dtype=float)

# %% [markdown]
# ## Save data for replot

# %%
value = np.concatenate([t, x, y, MSD, tau])
variable = np.concatenate([
    np.repeat("t_s", t.shape[0]),
    np.repeat("x_nm", x.shape[0]),
    np.repeat("y_nm", y.shape[0]),
    np.repeat("MSD_um2", MSD.shape[0]),
    np.repeat("tau_s", tau.shape[0]),
])
df_save = pd.DataFrame({
    "variable":variable,
    "value":value,
}, dtype=object)
df_save.to_csv(fname_save_prefix + "-data.csv", index=False)

# %% [markdown]
# # Plot RNA track

# %%
cmap = clr.LinearSegmentedColormap.from_list(
    cmap_name, [cmap_color_start, cmap_color_end], N=x.shape[0]
)

plt.figure(figsize=(5,6.5))
for i in range(len(t) - 1):
    plt.plot(
        x[i : i + 2],
        y[i : i + 2],
        "-o",
        color=cmap(i/ len(t)),
        linewidth=3,
    )
plt.axis("equal")
plt.xlabel("X, nm", weight='bold')
plt.ylabel("Y, nm", weight='bold')
cbar = plt.colorbar(cm.ScalarMappable(norm=clr.Normalize(t[0], t[-1]), cmap=cmap), ax=plt.gca(), orientation="horizontal", pad=0.11, fraction=0.15)
cbar.set_label(label='Time, s', weight='bold')
plt.savefig(fname_save_prefix + "-track-autoscale.png", format='png', dpi=600, bbox_inches='tight')
plt.xlim(-500, 500)
plt.ylim(-500, 500)
plt.savefig(fname_save_prefix + "-track-1umscale.png", format='png', dpi=600, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Plot MSD-tau

# %% [markdown]
# ## Equation:
#
# - MSD = 2 n D tau^alpha = 4 D tau^alpha
# - log(MSD) = alpha * log(tau) + log(D) + log(4)
# - slope = alpha; intercept = log(D) + log(4)

# %%
plt.figure(figsize=(5,3))
plt.plot(tau, MSD, color=color, ls='-', marker='o', label="All")
plt.xlabel("tau, s", weight='bold')
plt.ylabel(r"MSD, $\mu$m$^{2}$", weight='bold')
plt.savefig(fname_save_prefix + "-MSDtau.png", format='png', dpi=600, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(5,3))
plt.plot(tau, MSD, color=color, ls='-', marker='o', label="All")
plt.gca().set_yscale('log')
plt.gca().set_xscale('log')
plt.xlabel("tau, s", weight='bold')
plt.ylabel(r"MSD, $\mu$m$^{2}$", weight='bold')
plt.savefig(fname_save_prefix + "-MSDtau-loglog.png", format='png', dpi=600, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Max d to center

# %%
max_d_to_center = np.sqrt(np.max((x - x.mean())**2 + (y -  y.mean())**2))
d_to_center = np.sqrt((x - x.mean())**2 + (y -  y.mean())**2)
max_d_to_center
# Out:
# 74.88326039691823

# %% [markdown]
# ## Max d to start

# %%
max_d_to_start = np.sqrt(np.max((x - x[0])**2 + (y -  y[0])**2))
d_to_start = np.sqrt((x - x[0])**2 + (y -  y[0])**2)
max_d_to_start
# Out:
# 99.6494137891643

# %% [markdown]
# ## Max d between any two points

# %%
np.max(np.sqrt((x-np.atleast_2d(x).T)**2 + (y-np.atleast_2d(y).T)**2))
# Out:
# 129.2794760046434
