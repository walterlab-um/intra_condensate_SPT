# %% [markdown]
# ## Import

# %%
import os
from os.path import dirname
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as clr
from matplotlib import cm
import scipy.stats as stats
import seaborn as sns

sns.set(color_codes=True, style="white")
pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ## color and saving

# %%
color = "#9a3324"

cmap_color_start = "#00274C"
cmap_color_end = "#FFCB05"
cmap_name = "blue2maize"

folder_save = "/Volumes/lsa-nwalter/Guoming_Gao_turbo/Walterlab_server/PROCESSED_DATA/RNA-diffusion-in-FUS/RNAinFUS_PaperFigures/Fig2_diffusion analysis/example_zoomed_in_tracks"
os.chdir(folder_save)

fname_save_prefix = "zoomed_in_RNA_track-medium-1"
switch_read_from_file = True

# %% [markdown]
# ## Raw data for the track (Option 1: Mannualy input)

# %%
t = np.array([58, 59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80])

x = np.array([34.02935760745154, 33.59804327899997, 33.96924337204478, 32.90986754950131, 32.838359551386105, 32.88585526887609, 32.14332374147348, 32.918822638295616, 33.35223921821551, 34.10978536034375, 32.293792436057025, 33.87495545590359, 32.98153006985412, 33.25596466430297, 32.73933744834182, 33.09517477186635, 34.17244580242341, 32.828744811071665, 32.44847642186862, 33.627480322389815, 32.27001588559114, 32.37721288335855, 32.98833267055326])

y = np.array([79.57633344783893, 79.97440966255645, 80.22048891609911, 80.65141380208738, 80.45834360913193, 80.87013703473266, 80.92549103101477, 80.44206208645508, 80.64657545695694, 80.22234609568149, 81.0472850323964, 79.99515587295876, 81.09132453224368, 79.84822529586664, 80.89867578390779, 80.6097639934526, 80.21342188293403, 80.37529892012333, 80.66267892784985, 80.27485285083586, 80.7856295383185, 80.76015506715727, 80.12177404719527])

MSD = np.array([0.015579360336134438, 0.0122995241829872, 0.014520930202198796, 0.015294080201962795, 0.01901160777116098, 0.017617969766016553, 0.011688297430407654, 0.01323536493020672, 0.015871013994441806, 0.018526546527235548, 0.012080312412477172, 0.017591047471808965, 0.014514299258270122, 0.009323073358041653, 0.008722783844452261, 0.012525167853407708, 0.012083992294697705, 0.0202830983752674, 0.021161978518699838, 0.03484960885126101, 0.030967797224769545, 0.01890777200134919])

tau = np.arange(1, MSD.shape[0] + 1) * 0.02

length = MSD.shape[0]
half_length = round(length/2)

# %% [markdown]
# ## Transform to physical unit

# %%
nm_per_pxl = 117
s_per_frame = 0.02

x = (x - (x.min() + x.max())/2) * nm_per_pxl
y = (y - (y.min() + y.max())/2) * nm_per_pxl
t = (t - t[0]) * s_per_frame

# %% [markdown]
# ## Raw data for the track (Option 2: from file)

# %%
if switch_read_from_file:
    df_load = pd.read_csv(fname_save_prefix + "-data.csv")
    t = df_load[df_load["variable"] == "t_s"]["value"].to_numpy(dtype=float)
    x = df_load[df_load["variable"] == "x_nm"]["value"].to_numpy(dtype=float)
    y = df_load[df_load["variable"] == "y_nm"]["value"].to_numpy(dtype=float)
    MSD = df_load[df_load["variable"] == "MSD_um2"]["value"].to_numpy(dtype=float)
    tau = df_load[df_load["variable"] == "tau_s"]["value"].to_numpy(dtype=float)
    length = MSD.shape[0]
    half_length = round(length/2)

# %% [markdown]
# # Plot MSD-tau

# %% [markdown]
# ## Equation:
#
# - MSD = 2 n D tau^alpha = 4 D tau^alpha
# - log(MSD) = alpha * log(tau) + log(D) + log(4)
# - slope = alpha; intercept = log(D) + log(4)

# %%
plt.figure(figsize=(5,3))
plt.plot(tau[:half_length], MSD[:half_length], color=color, ls='-', marker='o', label="All")
plt.xlabel("tau, s", weight='bold')
plt.ylabel(r"MSD, $\mu$m$^{2}$", weight='bold')
plt.savefig(fname_save_prefix + "-MSDtau.png", format='png', dpi=600, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(5,3))
plt.plot(tau[:half_length], MSD[:half_length], color=color, ls='-', marker='o', label="All")
plt.gca().set_yscale('log')
plt.gca().set_xscale('log')
plt.xlabel("tau, s", weight='bold')
plt.ylabel(r"MSD, $\mu$m$^{2}$", weight='bold')
plt.savefig(fname_save_prefix + "-MSDtau-loglog.png", format='png', dpi=600, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Save data for replot

# %%
if not switch_read_from_file:
    value = np.concatenate([t, x, y, MSD, tau])
    variable = np.concatenate([
        np.repeat("t_s", t.shape[0]),
        np.repeat("x_nm", x.shape[0]),
        np.repeat("y_nm", y.shape[0]),
        np.repeat("MSD_um2", MSD.shape[0]),
        np.repeat("tau_s", tau.shape[0]),
    ])
    df_save = pd.DataFrame({
        "variable":variable,
        "value":value,
    }, dtype=object)
    df_save.to_csv(fname_save_prefix + "-data.csv", index=False)

# %% [markdown]
# # Plot RNA track

# %%
cmap = clr.LinearSegmentedColormap.from_list(
    cmap_name, [cmap_color_start, cmap_color_end], N=x.shape[0]
)

plt.figure(figsize=(5,6.5))
for i in range(len(t) - 1):
    plt.plot(
        x[i : i + 2],
        y[i : i + 2],
        "-o",
        color=cmap(i/ len(t)),
        linewidth=3,
    )
plt.axis("equal")
plt.xlabel("X, nm", weight='bold')
plt.ylabel("Y, nm", weight='bold')
cbar = plt.colorbar(cm.ScalarMappable(norm=clr.Normalize(t[0], t[-1]), cmap=cmap), ax=plt.gca(), orientation="horizontal", pad=0.11, fraction=0.15)
cbar.set_label(label='Time, s', weight='bold')
# plt.savefig(fname_save_prefix + "-track-autoscale.png", format='png', dpi=600, bbox_inches='tight')
# plt.xlim(-500, 500)
# plt.ylim(-500, 500)
# plt.savefig(fname_save_prefix + "-track-1umscale.png", format='png', dpi=600, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Max d to center

# %%
max_d_to_center = np.sqrt(np.max((x - x.mean())**2 + (y -  y.mean())**2))
d_to_center = np.sqrt((x - x.mean())**2 + (y -  y.mean())**2)
max_d_to_center
# Out:
# 265.13036328296334

# %% [markdown]
# ## Max d to start

# %%
max_d_to_start = np.sqrt(np.max((x - x[0])**2 + (y -  y[0])**2))
d_to_start = np.sqrt((x - x[0])**2 + (y -  y[0])**2)
max_d_to_start
# Out:
# 355.82873176791696

# %% [markdown]
# ## Max d between any two points

# %%
np.max(np.sqrt((x-np.atleast_2d(x).T)**2 + (y-np.atleast_2d(y).T)**2))
# Out:
# 456.34645104216236

# %% [markdown]
# ## Convex Hull equivalent diameter

# %%
from scipy.spatial import ConvexHull

points_coordinates_nm = np.stack([x, y], axis=-1)
convex_area_nm2 = ConvexHull(
    points_coordinates_nm
).volume  # bug fix: ConvexHull.area is perimeter in 2d
equivalent_d_nm = np.sqrt(convex_area_nm2 / np.pi) * 2
equivalent_d_nm
# Out:
# 288.91502231790656
