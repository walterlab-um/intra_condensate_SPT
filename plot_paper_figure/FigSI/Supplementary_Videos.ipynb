# %%
import os
from os.path import exists, join

import matplotlib.animation as animation
import matplotlib.colors as clr
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tifffile import imread, imwrite
import ffmpeg
from matplotlib.animation import FuncAnimation

pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ### Fig3 escape of RNA

# %%
um_per_pixel = 0.117
s_per_frame = 0.02
folder_data = "/Volumes/lsa-nwalter/Guoming_Gao_turbo/Walterlab_server/PROCESSED_DATA/RNA-diffusion-in-FUS/paper_figure_plots/Fig3_specs to functions/multi_stage_diffusion_examples/selected_montage"
folder_save = "/Volumes/AnalysisGG/Dropbox/Writing/MyPublications/SMT_FUS_Nanodomain-Nat2024"

os.chdir(folder_data)
video = imread("Merged_cropped_3stage_leaving.tif")
df = pd.read_csv("track.csv")
df = df.sort_values("t")

plow = 0.5  # imshow intensity percentile
phigh = 90
scalebar_color = "white"

cmap_blue = clr.LinearSegmentedColormap.from_list(
    "dark2blue",
    ["black", "#B9DBF4"],
)
cmap_red = clr.LinearSegmentedColormap.from_list(
    "transparent2red",
    [(0.753, 0.22, 0.188, 0), (0.753, 0.22, 0.188, 1)],
)
N = df.shape[0]
cmap = clr.LinearSegmentedColormap.from_list("maize2blue", ["#FFCB05", "#00274C"], N=N)

scalebar_length_um = 1
scalebar_length_pxl = scalebar_length_um / um_per_pixel
scale_bar_offset = 1

fig, ax = plt.subplots(1, 1)
all_avaliable_frames = set(df["t"].unique())


def animate(frame):
    ax.clear()
    img_blue = video[frame - 1, 1, :, :]
    img_red = video[frame - 1, 0, :, :]
    plt.imshow(
        img_blue,
        cmap=cmap_blue,
        vmin=3100,
        vmax=5600,
    )
    plt.imshow(
        img_red,
        cmap=cmap_red,
        vmin=2,
        vmax=6,
    )
    # add time stamp
    plt.text(
        0,
        1,
        str(round(frame * s_per_frame, 2)) + " s",
        color="white",
        weight="bold",
        size=25,
    )
    # add color labels
    plt.text(
        0,
        6,
        "FUS bulk",
        color="#B9DBF4",
        weight="bold",
        size=17,
    )
    plt.text(
        0,
        7,
        "mRNA SMT",
        color="#eb4034",
        weight="bold",
        size=17,
    )

    # Add a single current circle, except for gaps
    if frame - 1 in all_avaliable_frames:
        current_x = df[df["t"] == frame - 1]["x"].squeeze()
        current_y = df[df["t"] == frame - 1]["y"].squeeze()
        c = plt.Circle(
            (current_x, current_y),
            1.3,
            color="white",
            fill=False,
            lw=2,
        )
        ax.add_patch(c)
    # Add a single track
    track = df[df["t"] <= frame - 1]
    t_plot = track["t"].to_numpy(float)
    x_plot = track["x"].to_numpy(float)
    y_plot = track["y"].to_numpy(float)
    for i in range(len(t_plot) - 1):
        plt.plot(
            x_plot[i : i + 2],
            y_plot[i : i + 2],
            "-o",
            color=cmap(i / N),
            lw=2,
        )
    # scale bar
    scale_bar_offset = 0
    scalebar_length_um = 1
    base_x = 11.1
    base_y = 6.7
    scalebar_length_pxl = scalebar_length_um / um_per_pixel
    plt.plot(
        [
            base_x + scale_bar_offset,
            base_x + scale_bar_offset + scalebar_length_pxl,
        ],
        [base_y + scale_bar_offset, base_y + scale_bar_offset],
        "-",
        color="white",
        lw=5,
    )
    plt.xlim(0, img_blue.shape[0])
    plt.ylim(0, img_blue.shape[1])
    ax.invert_yaxis()
    plt.tight_layout()
    plt.axis("scaled")
    plt.axis("off")

# animate(5)
ani = FuncAnimation(fig, animate, frames=150, interval=20, repeat=False)
writer = animation.FFMpegWriter(fps=25)  # 25 Hz, 0.5x playback (original:50Hz)
ani.save(join(folder_save, "VideoS_RNA_escape.mp4"), writer=writer, dpi=600)

# %% [markdown]
# ### SMT-PAINT of FUS

# %%
um_per_pixel = 0.117
s_per_frame = 0.04
folder_data = "/Volumes/lsa-nwalter/Guoming_Gao_turbo/Walterlab_server/PROCESSED_DATA/RNA-diffusion-in-FUS/RNAinFUS_PaperFigures/Supp_videos/SMTPAINT-FUS-FL"
folder_save = "/Users/GGM/Documents/Graduate_Work/Nils_Walter_Lab/Writing/MyPublications/SMT_FUS_Nanodomain-Nat2024"

os.chdir(folder_data)
video = imread("20230928-FOV-4-single_condensate-left-bandpass.tif")
df = pd.read_csv("20230928-FOV-4-single_condensate-left_reformatted.csv")
df = df.sort_values("t")

vmin = 5  # imshow intensity
vmax = 25
scalebar_color = "white"

cmap_blue = clr.LinearSegmentedColormap.from_list(
    "dark2blue",
    ["black", "#B9DBF4"],
)
track_color = "#ee9b00"
circ_size = 2.5

scale_bar_offset = 0
scalebar_length_um = 1
base_x = 27
base_y = 36
scalebar_length_pxl = scalebar_length_um / um_per_pixel
scale_bar_offset = 1
time_stamp_x = 1
time_stamp_y = 3
label_x = 1
label_y = 38
label_blue = "FUS"
color_blue = "#B9DBF4"

fig, ax = plt.subplots(1, 1)
all_avaliable_frames = set(df["t"].unique())


def animate(frame):
    ax.clear()
    img_blue = video[frame - 1, :, :]
    plt.imshow(
        img_blue,
        cmap=cmap_blue,
        vmin=vmin,
        vmax=vmax,
    )
    # add time stamp
    plt.text(
        time_stamp_x,
        time_stamp_y,
        str(round(frame * s_per_frame, 2)) + " s",
        color="white",
        weight="bold",
        size=25,
    )
    # add color label
    plt.text(
        label_x,
        label_y,
        label_blue,
        color=color_blue,
        weight="bold",
        size=25,
    )

    # Add all current circle, except for gaps
    if frame - 1 in all_avaliable_frames:
        current_x = df[df["t"] == frame - 1]["x"].to_numpy(float)
        current_y = df[df["t"] == frame - 1]["y"].to_numpy(float)
        for circ_x, circ_y in zip(current_x, current_y):
            c = plt.Circle(
                (circ_x, circ_y),
                circ_size,
                color=track_color,
                fill=False,
                lw=1,
            )
            ax.add_patch(c)
    # Add all current tracks before this frame
    all_tracks_before = df[df["t"] <= frame - 1]
    for trackID in all_tracks_before["trackID"].unique():
        track = all_tracks_before[all_tracks_before["trackID"] == trackID]
        if (
            track["t"].max() < frame - 1
        ):  # remove tracks that are aready ended before the current frame
            continue
        x_plot = track["x"].to_numpy(float)
        y_plot = track["y"].to_numpy(float)
        plt.plot(
            x_plot,
            y_plot,
            "-o",
            color=track_color,
            lw=2,
        )
    # scale bar
    plt.plot(
        [
            base_x + scale_bar_offset,
            base_x + scale_bar_offset + scalebar_length_pxl,
        ],
        [base_y + scale_bar_offset, base_y + scale_bar_offset],
        "-",
        color="white",
        lw=5,
    )
    plt.xlim(0, img_blue.shape[0])
    plt.ylim(0, img_blue.shape[1])
    ax.invert_yaxis()
    plt.tight_layout()
    plt.axis("scaled")
    plt.axis("off")

# animate(5)
ani = FuncAnimation(fig, animate, frames=5000, interval=10, repeat=False)
writer = animation.FFMpegWriter(fps=10)
ani.save(join(folder_save, "VideoS_SMT_PAINT_FUS.mp4"), writer=writer)

# %% [markdown]
# ### SMT-PAINT of FL RNA

# %%
um_per_pixel = 0.117
s_per_frame = 0.04
folder_data = "/Volumes/lsa-nwalter/Guoming_Gao_turbo/Walterlab_server/PROCESSED_DATA/RNA-diffusion-in-FUS/RNAinFUS_PaperFigures/Supp_videos/SMTPAINT-FUS-FL"
folder_save = "/Users/GGM/Documents/Graduate_Work/Nils_Walter_Lab/Writing/MyPublications/SMT_FUS_Nanodomain-Nat2024"

os.chdir(folder_data)
video = imread("20230928-FOV-4-single_condensate-right-bandpass.tif")
df = pd.read_csv("20230928-FOV-4-single_condensate-right_reformatted.csv")
df = df.sort_values("t")

vmin = 0  # imshow intensity
vmax = 30
scalebar_color = "white"

cmap_red = clr.LinearSegmentedColormap.from_list(
    "dark2red",
    ["black", "#eb4034"],
)
track_color = "#ee9b00"
circ_size = 2.5

scale_bar_offset = 0
scalebar_length_um = 1
base_x = 27
base_y = 36
scalebar_length_pxl = scalebar_length_um / um_per_pixel
scale_bar_offset = 1
time_stamp_x = 1
time_stamp_y = 3
label_x = 1
label_y = 38
label_red = "mRNA"
color_red = "#eb4034"

fig, ax = plt.subplots(1, 1)
all_avaliable_frames = set(df["t"].unique())


def animate(frame):
    ax.clear()
    img_red = video[frame - 1, :, :]
    plt.imshow(
        img_red,
        cmap=cmap_red,
        vmin=vmin,
        vmax=vmax,
    )
    # add time stamp
    plt.text(
        time_stamp_x,
        time_stamp_y,
        str(round(frame * s_per_frame, 2)) + " s",
        color="white",
        weight="bold",
        size=25,
    )
    # add color label
    plt.text(
        label_x,
        label_y,
        label_red,
        color=color_red,
        weight="bold",
        size=25,
    )

    # Add all current circle, except for gaps
    if frame - 1 in all_avaliable_frames:
        current_x = df[df["t"] == frame - 1]["x"].to_numpy(float)
        current_y = df[df["t"] == frame - 1]["y"].to_numpy(float)
        for circ_x, circ_y in zip(current_x, current_y):
            c = plt.Circle(
                (circ_x, circ_y),
                circ_size,
                color=track_color,
                fill=False,
                lw=1,
            )
            ax.add_patch(c)
    # Add all current tracks before this frame
    all_tracks_before = df[df["t"] <= frame - 1]
    for trackID in all_tracks_before["trackID"].unique():
        track = all_tracks_before[all_tracks_before["trackID"] == trackID]
        if (
            track["t"].max() < frame - 1
        ):  # remove tracks that are aready ended before the current frame
            continue
        x_plot = track["x"].to_numpy(float)
        y_plot = track["y"].to_numpy(float)
        plt.plot(
            x_plot,
            y_plot,
            "-o",
            color=track_color,
            lw=2,
        )
    # scale bar
    plt.plot(
        [
            base_x + scale_bar_offset,
            base_x + scale_bar_offset + scalebar_length_pxl,
        ],
        [base_y + scale_bar_offset, base_y + scale_bar_offset],
        "-",
        color="white",
        lw=5,
    )
    plt.xlim(0, img_red.shape[0])
    plt.ylim(0, img_red.shape[1])
    ax.invert_yaxis()
    plt.tight_layout()
    plt.axis("scaled")
    plt.axis("off")

# animate(500)
ani = FuncAnimation(fig, animate, frames=5000, interval=10, repeat=False)
writer = animation.FFMpegWriter(fps=10)
ani.save(join(folder_save, "VideoS_SMT_PAINT_FL.mp4"), writer=writer)

# %% [markdown]
# ### SMT-PAINT FUS-FL together

# %%
um_per_pixel = 0.117
s_per_frame = 0.04
folder_data = "/Volumes/lsa-nwalter/Guoming_Gao_turbo/Walterlab_server/PROCESSED_DATA/RNA-diffusion-in-FUS/RNAinFUS_PaperFigures/Supp_videos/SMTPAINT-FUS-FL"
folder_save = "/Users/GGM/Documents/Graduate_Work/Nils_Walter_Lab/Writing/MyPublications/SMT_FUS_Nanodomain-Nat2024"

os.chdir(folder_data)
video_left = imread("20230928-FOV-4-single_condensate-left-bandpass.tif")
video_right = imread("20230928-FOV-4-single_condensate-right-bandpass.tif")
df_left = pd.read_csv("20230928-FOV-4-single_condensate-left_reformatted.csv")
df_right = pd.read_csv("20230928-FOV-4-single_condensate-right_reformatted.csv")
df_left = df_left.sort_values("t")
df_right = df_right.sort_values("t")

vmin_blue = 5
vmax_blue = 25
vmin_red = 0
vmax_red = 30
scalebar_color = "white"

cmap_blue = clr.LinearSegmentedColormap.from_list("dark2blue", ["black", "#B9DBF4"])
cmap_red = clr.LinearSegmentedColormap.from_list("dark2red", ["black", "#eb4034"])
track_color = "#ee9b00"
circ_size = 2.5

scale_bar_offset = 0
scalebar_length_um = 1
base_x = 27
base_y = 36
scalebar_length_pxl = scalebar_length_um / um_per_pixel
scale_bar_offset = 1
time_stamp_x = 1
time_stamp_y = 3
label_x = 1
label_y = 38
label_blue = "FUS"
color_blue = "#B9DBF4"
label_red = "FL mRNA"
color_red = "#eb4034"

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
all_avaliable_frames_left = set(df_left["t"].unique())
all_avaliable_frames_right = set(df_right["t"].unique())


def animate(frame):
    ax1.clear()
    ax2.clear()

    # Left animation
    img_blue = video_left[frame - 1, :, :]
    ax1.imshow(img_blue, cmap=cmap_blue, vmin=vmin_blue, vmax=vmax_blue)
    ax1.text(
        time_stamp_x,
        time_stamp_y,
        str(round(frame * s_per_frame, 2)) + " s",
        color="white",
        weight="bold",
        size=25,
    )
    ax1.text(
        label_x,
        label_y,
        label_blue,
        color=color_blue,
        weight="bold",
        size=25,
    )

    if frame - 1 in all_avaliable_frames_left:
        current_x = df_left[df_left["t"] == frame - 1]["x"].to_numpy(float)
        current_y = df_left[df_left["t"] == frame - 1]["y"].to_numpy(float)
        for circ_x, circ_y in zip(current_x, current_y):
            c = plt.Circle(
                (circ_x, circ_y), circ_size, color=track_color, fill=False, lw=1
            )
            ax1.add_patch(c)

    all_tracks_before = df_left[df_left["t"] <= frame - 1]
    for trackID in all_tracks_before["trackID"].unique():
        track = all_tracks_before[all_tracks_before["trackID"] == trackID]
        if track["t"].max() < frame - 1:
            continue
        x_plot = track["x"].to_numpy(float)
        y_plot = track["y"].to_numpy(float)
        ax1.plot(x_plot, y_plot, "-o", color=track_color, lw=2)

    ax1.plot(
        [base_x + scale_bar_offset, base_x + scale_bar_offset + scalebar_length_pxl],
        [base_y + scale_bar_offset, base_y + scale_bar_offset],
        "-",
        color="white",
        lw=5,
    )
    ax1.set_xlim(0, img_blue.shape[0])
    ax1.set_ylim(0, img_blue.shape[1])
    ax1.invert_yaxis()
    ax1.axis("scaled")
    ax1.axis("off")

    # Right animation
    img_red = video_right[frame - 1, :, :]
    ax2.imshow(img_red, cmap=cmap_red, vmin=vmin_red, vmax=vmax_red)
    ax2.text(
        time_stamp_x,
        time_stamp_y,
        str(round(frame * s_per_frame, 2)) + " s",
        color="white",
        weight="bold",
        size=25,
    )
    ax2.text(
        label_x,
        label_y,
        label_red,
        color=color_red,
        weight="bold",
        size=25,
    )

    if frame - 1 in all_avaliable_frames_right:
        current_x = df_right[df_right["t"] == frame - 1]["x"].to_numpy(float)
        current_y = df_right[df_right["t"] == frame - 1]["y"].to_numpy(float)
        for circ_x, circ_y in zip(current_x, current_y):
            c = plt.Circle(
                (circ_x, circ_y), circ_size, color=track_color, fill=False, lw=1
            )
            ax2.add_patch(c)

    all_tracks_before = df_right[df_right["t"] <= frame - 1]
    for trackID in all_tracks_before["trackID"].unique():
        track = all_tracks_before[all_tracks_before["trackID"] == trackID]
        if track["t"].max() < frame - 1:
            continue
        x_plot = track["x"].to_numpy(float)
        y_plot = track["y"].to_numpy(float)
        ax2.plot(x_plot, y_plot, "-o", color=track_color, lw=2)

    ax2.plot(
        [base_x + scale_bar_offset, base_x + scale_bar_offset + scalebar_length_pxl],
        [base_y + scale_bar_offset, base_y + scale_bar_offset],
        "-",
        color="white",
        lw=5,
    )
    ax2.set_xlim(0, img_red.shape[0])
    ax2.set_ylim(0, img_red.shape[1])
    ax2.invert_yaxis()
    ax2.axis("scaled")
    ax2.axis("off")

    plt.tight_layout()


# animate(5)
ani = FuncAnimation(fig, animate, frames=5000, interval=10, repeat=False)
writer = animation.FFMpegWriter(fps=10)
ani.save(join(folder_save, "VideoS_SMT_PAINT_FUS-FL.mp4"), writer=writer, dpi=300)

# %% [markdown]
# ### SMT-PAINT FUS-miRNA21 together

# %%
um_per_pixel = 0.117
s_per_frame = 0.04
folder_data = "/Volumes/lsa-nwalter/Guoming_Gao_turbo/Walterlab_server/PROCESSED_DATA/RNA-diffusion-in-FUS/RNAinFUS_PaperFigures/Supp_videos/SMTPAINT-FUS-miR21"
folder_save = "/Users/GGM/Documents/Graduate_Work/Nils_Walter_Lab/Writing/MyPublications/SMT_FUS_Nanodomain-Nat2024"

os.chdir(folder_data)
video_left = imread("20230928-miR21_FUS_FOV-1-single_condensate-left-bandpass.tif")
video_right = imread("20230928-miR21_FUS_FOV-1-single_condensate-right-bandpass.tif")
df_left = pd.read_csv("20230928-miR21_FUS_FOV-1-single_condensate-left_reformatted.csv")
df_right = pd.read_csv(
    "20230928-miR21_FUS_FOV-1-single_condensate-right_reformatted.csv"
)
df_left = df_left.sort_values("t")
df_right = df_right.sort_values("t")

vmin_blue = 5
vmax_blue = 20
vmin_red = 5
vmax_red = 20
scalebar_color = "white"

cmap_blue = clr.LinearSegmentedColormap.from_list("dark2blue", ["black", "#B9DBF4"])
cmap_red = clr.LinearSegmentedColormap.from_list("dark2red", ["black", "#eb4034"])
track_color = "#ee9b00"
circ_size = 2.5

scale_bar_offset = 0
scalebar_length_um = 1
base_x = 30
base_y = 38.5
scalebar_length_pxl = scalebar_length_um / um_per_pixel
scale_bar_offset = 1
time_stamp_x = 1
time_stamp_y = 3
label_x = 1
label_y = 40
label_blue = "FUS"
color_blue = "#B9DBF4"
label_red = "miRNA-21"
color_red = "#eb4034"

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
all_avaliable_frames_left = set(df_left["t"].unique())
all_avaliable_frames_right = set(df_right["t"].unique())


def animate(frame):
    ax1.clear()
    ax2.clear()

    # Left animation
    img_blue = video_left[frame - 1, :, :]
    ax1.imshow(img_blue, cmap=cmap_blue, vmin=vmin_blue, vmax=vmax_blue)
    ax1.text(
        time_stamp_x,
        time_stamp_y,
        str(round(frame * s_per_frame, 2)) + " s",
        color="white",
        weight="bold",
        size=25,
    )
    ax1.text(
        label_x,
        label_y,
        label_blue,
        color=color_blue,
        weight="bold",
        size=25,
    )

    if frame - 1 in all_avaliable_frames_left:
        current_x = df_left[df_left["t"] == frame - 1]["x"].to_numpy(float)
        current_y = df_left[df_left["t"] == frame - 1]["y"].to_numpy(float)
        for circ_x, circ_y in zip(current_x, current_y):
            c = plt.Circle(
                (circ_x, circ_y), circ_size, color=track_color, fill=False, lw=1
            )
            ax1.add_patch(c)

    all_tracks_before = df_left[df_left["t"] <= frame - 1]
    for trackID in all_tracks_before["trackID"].unique():
        track = all_tracks_before[all_tracks_before["trackID"] == trackID]
        if track["t"].max() < frame - 1:
            continue
        x_plot = track["x"].to_numpy(float)
        y_plot = track["y"].to_numpy(float)
        ax1.plot(x_plot, y_plot, "-o", color=track_color, lw=2)

    ax1.plot(
        [base_x + scale_bar_offset, base_x + scale_bar_offset + scalebar_length_pxl],
        [base_y + scale_bar_offset, base_y + scale_bar_offset],
        "-",
        color="white",
        lw=5,
    )
    ax1.set_xlim(0, img_blue.shape[0])
    ax1.set_ylim(0, img_blue.shape[1])
    ax1.invert_yaxis()
    ax1.axis("scaled")
    ax1.axis("off")

    # Right animation
    img_red = video_right[frame - 1, :, :]
    ax2.imshow(img_red, cmap=cmap_red, vmin=vmin_red, vmax=vmax_red)
    ax2.text(
        time_stamp_x,
        time_stamp_y,
        str(round(frame * s_per_frame, 2)) + " s",
        color="white",
        weight="bold",
        size=25,
    )
    ax2.text(
        label_x,
        label_y,
        label_red,
        color=color_red,
        weight="bold",
        size=25,
    )

    if frame - 1 in all_avaliable_frames_right:
        current_x = df_right[df_right["t"] == frame - 1]["x"].to_numpy(float)
        current_y = df_right[df_right["t"] == frame - 1]["y"].to_numpy(float)
        for circ_x, circ_y in zip(current_x, current_y):
            c = plt.Circle(
                (circ_x, circ_y), circ_size, color=track_color, fill=False, lw=1
            )
            ax2.add_patch(c)

    all_tracks_before = df_right[df_right["t"] <= frame - 1]
    for trackID in all_tracks_before["trackID"].unique():
        track = all_tracks_before[all_tracks_before["trackID"] == trackID]
        if track["t"].max() < frame - 1:
            continue
        x_plot = track["x"].to_numpy(float)
        y_plot = track["y"].to_numpy(float)
        ax2.plot(x_plot, y_plot, "-o", color=track_color, lw=2)

    ax2.plot(
        [base_x + scale_bar_offset, base_x + scale_bar_offset + scalebar_length_pxl],
        [base_y + scale_bar_offset, base_y + scale_bar_offset],
        "-",
        color="white",
        lw=5,
    )
    ax2.set_xlim(0, img_red.shape[0])
    ax2.set_ylim(0, img_red.shape[1])
    ax2.invert_yaxis()
    ax2.axis("scaled")
    ax2.axis("off")

    plt.tight_layout()


# animate(50)
ani = FuncAnimation(fig, animate, frames=5000, interval=10, repeat=False)
writer = animation.FFMpegWriter(fps=10)
ani.save(join(folder_save, "VideoS_SMT_PAINT_FUS-miR21.mp4"), writer=writer, dpi=300)

# %% [markdown]
# ### FL SMT in bulk FUS

# %%
folder_data = "/Volumes/lsa-nwalter/Guoming_Gao_turbo/Walterlab_server/PROCESSED_DATA/RNA-diffusion-in-FUS/RNAinFUS_PaperFigures/Supp_videos/FL-SMT-FUSbulk"
os.chdir(folder_data)
fname = "SPT_results_AIO_concat-0Dex_noTR_0hr.csv"
df = pd.read_csv(fname)
df_mobile = df[df["mean_stepsize_nm"] > 50]
df_confined = df_mobile[df_mobile["alpha"] < 0.7]
# find the best FOV with most confined trajectories
indexed_series = df_confined["filename"].value_counts()
indexed_series[:5]
# Out:
# SPT_results_AIO-20221031-FL_noTR_noDex_20ms_0hr_Replicate1_FOV-7-RNAs.csv    2037
# SPT_results_AIO-20230628-FL_noTR_noDex_20ms_0hr_replicate3_FOV-RNAs.csv      1987
# SPT_results_AIO-20230628-FL_noTR_noDex_20ms_0hr_replicate2_FOV-7-RNAs.csv    1236
# SPT_results_AIO-20230628-FL_noTR_noDex_20ms_0hr_replicate3_FOV-4-RNAs.csv    1184
# SPT_results_AIO-20230628-FL_noTR_noDex_20ms_0hr_replicate3_FOV-5-RNAs.csv    1179
# Name: filename, dtype: int64

# %%
# img_condensate = imread(
#     "20221031-FL_noTR_20ms_Replicate1_FOV-7-condensates_AveProj.tif"
# )
# video_RNA = imread("20221031-FL_noTR_20ms_Replicate1_FOV-7-RNAs-bandpass.tif")
# video_condensate = np.stack([img_condensate for i in range(video_RNA.shape[0])])
# combined_video = np.stack(
#     (video_RNA.astype(np.uint16), video_condensate.astype(np.uint16)), axis=1
# )
# # Save the combined video as a multi-channel TIFF file with color mapping
# imwrite(
#     "two_channel_video.tif",
#     combined_video,
#     imagej=True,
#     metadata={"axes": "TCYX", "mode": "composite"},
#     photometric="palette",
# )

# %%
video = imread("20221031-FL_Rep1_FOV-7-combined-zoom-1.tif")
video.shape
# Out:
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# (200, 2, 45, 45)

# %%
um_per_pixel = 0.117
s_per_frame = 0.04
folder_data = "/Volumes/lsa-nwalter/Guoming_Gao_turbo/Walterlab_server/PROCESSED_DATA/RNA-diffusion-in-FUS/RNAinFUS_PaperFigures/Supp_videos/FL-SMT-FUSbulk"
folder_save = "/Users/GGM/Documents/Graduate_Work/Nils_Walter_Lab/Writing/MyPublications/SMT_FUS_Nanodomain-Nat2024"

os.chdir(folder_data)
video = imread("20221031-FL_Rep1_FOV-7-combined-zoom-1.tif")
df = pd.read_csv("20221031-FL_Rep1_FOV-7-combined-zoom-1_reformatted.csv")
df = df.sort_values("t")

vmin_blue = 800
vmax_blue = 3000
vmin_red = 5
vmax_red = 15
scalebar_color = "white"

cmap_blue = clr.LinearSegmentedColormap.from_list(
    "dark2blue",
    ["black", "#B9DBF4"],
)
cmap_red = clr.LinearSegmentedColormap.from_list(
    "transparent2red",
    [(0.753, 0.22, 0.188, 0), (0.753, 0.22, 0.188, 1)],
)
track_color = "#ee9b00"
circ_size = 2.5

scale_bar_offset = 0
scalebar_length_um = 1
base_x = 32
base_y = 41
scalebar_length_pxl = scalebar_length_um / um_per_pixel
scale_bar_offset = 1
time_stamp_x = 1
time_stamp_y = 4
label_x = 1
label_y = 43
label_blue = "FUS bulk"
label_red = "mRNA SMT"
color_blue = "#B9DBF4"

fig, ax = plt.subplots(1, 1)
all_avaliable_frames = set(df["t"].unique())


def animate(frame):
    ax.clear()
    img_blue = video[frame - 1, 1, :, :]
    img_red = video[frame - 1, 0, :, :]
    plt.imshow(
        img_blue,
        cmap=cmap_blue,
        vmin=vmin_blue,
        vmax=vmax_blue,
    )
    plt.imshow(
        img_red,
        cmap=cmap_red,
        vmin=vmin_red,
        vmax=vmax_red,
    )
    # add time stamp
    plt.text(
        time_stamp_x,
        time_stamp_y,
        str(round(frame * s_per_frame, 2)) + " s",
        color="white",
        weight="bold",
        size=25,
    )
    # add color labels
    plt.text(
        label_x,
        label_y - 2.5,
        label_blue,
        color=color_blue,
        weight="bold",
        size=15,
    )
    plt.text(
        label_x,
        label_y,
        label_red,
        color=color_red,
        weight="bold",
        size=15,
    )

    # Add all current circle, except for gaps
    if frame - 1 in all_avaliable_frames:
        current_x = df[df["t"] == frame - 1]["x"].to_numpy(float)
        current_y = df[df["t"] == frame - 1]["y"].to_numpy(float)
        for circ_x, circ_y in zip(current_x, current_y):
            c = plt.Circle(
                (circ_x, circ_y),
                circ_size,
                color=track_color,
                fill=False,
                lw=1,
            )
            ax.add_patch(c)
    # Add all current tracks before this frame
    all_tracks_before = df[df["t"] <= frame - 1]
    for trackID in all_tracks_before["trackID"].unique():
        track = all_tracks_before[all_tracks_before["trackID"] == trackID]
        if (
            track["t"].max() < frame - 1
        ):  # remove tracks that are aready ended before the current frame
            continue
        x_plot = track["x"].to_numpy(float)
        y_plot = track["y"].to_numpy(float)
        plt.plot(
            x_plot,
            y_plot,
            "-o",
            color=track_color,
            lw=1,
        )
    # scale bar
    plt.plot(
        [
            base_x + scale_bar_offset,
            base_x + scale_bar_offset + scalebar_length_pxl,
        ],
        [base_y + scale_bar_offset, base_y + scale_bar_offset],
        "-",
        color="white",
        lw=5,
    )
    plt.xlim(0, img_blue.shape[0])
    plt.ylim(0, img_blue.shape[1])
    ax.invert_yaxis()
    plt.tight_layout()
    plt.axis("scaled")
    plt.axis("off")


# animate(5)
ani = FuncAnimation(fig, animate, frames=video.shape[0], interval=10, repeat=False)
writer = animation.FFMpegWriter(fps=10)
ani.save(join(folder_save, "VideoS_FL_SMT_FUSbulk.mp4"), writer=writer, dpi=600)
# Out:
# TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
